# %% [markdown]
# # Housing Price Prediction — ETL & Data Exploration
#
# **Author:** Daeren Kim
# **Project:** Housing Price Prediction Dashboard
# **Notebook:** ETL (Extract, Transform, Load) & Initial Data Exploration
# **Date:** 29/11/2025
#
# ---
#
# ## Overview
# This notebook performs the ETL process for the Housing Price dataset.
# Tasks include:
# - Importing raw data
# - Cleaning missing and inconsistent values
# - Feature engineering
# - Exploratory data analysis (EDA)
# - Saving processed data for model training and dashboard use
#
# ---

# %% [markdown]
# ## 1) Import Libraries

# %%
import pandas as pd
import numpy as np
